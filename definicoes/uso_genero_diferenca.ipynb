# %%
# Exemplificando uso de definições por gênero e diferença
#
# Autor: Fabrício Galende Marques de Carvalho

from modelo_genero_diferenca import Aluno

aluno_1 = Aluno("Thales", "Engenharia da Computação")
aluno_2 = Aluno("Eduardo", "Medicina")
aluna_1 = Aluno("Fabíola", "Direito")


aluno_1.apresentar_se()
aluno_2.apresentar_se()
aluna_1.apresentar_se()
# Out:
# Meu nome é  Thales
# Sou aluno(a) do curso de  Engenharia da Computação
# Meu nome é  Eduardo
# Sou aluno(a) do curso de  Medicina
# Meu nome é  Fabíola
# Sou aluno(a) do curso de  Direito
