# %%
# Exemplificando uso de definições por gênero e diferença
#
# Autor: Fabrício Galende Marques de Carvalho

from modelo_genero_diferenca import Aluno

aluno = Aluno("Thales", "Computação Aplicada")
aluna = Aluno("Fabíola", "Direito")

aluno.apresentar_se()
aluna.apresentar_se()
# Out:
# Meu nome é  Thales
# Sou aluno(a) do curso de  Computação Aplicada
# Meu nome é  Fabíola
# Sou aluno(a) do curso de  Direito
