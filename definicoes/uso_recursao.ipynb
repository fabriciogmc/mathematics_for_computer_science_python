# %%
# Exemplo de geração de números pares positivos utilizando
# uma definição recursiva
#
# Autor: Fabrício Galende Marques de Carvalho

from modelo_recursao import NumeroParPositivo


par_positivo = NumeroParPositivo()

primeiro_par = par_positivo.n_esimo_par(1)
segundo_par = par_positivo.n_esimo_par(2)
decimo_par = par_positivo.n_esimo_par(10)

print("Primeiro número par positivo: ", primeiro_par )
print("Segundo número par positivo: ", segundo_par)
print("Décimo número par positivo: ", decimo_par)
# Out:
# Primeiro número par positivo:  2
# Segundo número par positivo:  4
# Décimo número par positivo:  20
