# %%
# Exemplo de utilização de enumerações
# 
# Autor: Fabrício Galende Marques de Carvalho

from modelo_enumeracoes import Mes
from IPython.display import display, HTML


display(HTML( "No mês de " +  Mes.DEZEMBRO.name + " é comemorado o Natal. "))
display(HTML( "Esse é o " + str(Mes.DEZEMBRO.value) + "<sup>o</sup>" + " mês do ano."))
# Out:
# No mês de DEZEMBRO é comemorado o Natal.
# Esse é o 12<sup>o</sup> mês do ano.
